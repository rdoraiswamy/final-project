# %% [markdown]
# <a href="https://colab.research.google.com/github/rdoraiswamy/final-project/blob/master/WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ##############################################################
# Uncomment and run this to install the necessary modules
# After installation comment this back on
# ##############################################################

#!pip install multidict
#!pip install wordcloud

# %%
# ##############################################################
# Copy and past the Job Description here. Remove blank lines.
# ##############################################################
mytext = """
About the team

The team's goal is building tools to scale Zillow Group's financial operations including processing payments, accounting, tax, financial forecasting and many others. We do this by building custom tools and system integrations across SaaS and Zillow built applications. You will be adaptable, display leadership qualities, and pursue and tackle new problems as we continue to push technology forward.

The team enjoys a good challenge and we celebrate our successes together. If you enjoy working in a supportive environment that encourages creativity and promotes ownership and career growth, come and join us!
About the role

Are you passionate about growing the careers of your team members while remaining deep in technical details? As a Principal Technical Program Manager on this team, you'll get to contribute your technical expertise while building strong people management skills.

Program Managers at Zillow Group collaborate with business leads, product managers, and developers to ensure the success of product efforts. They also serve as technical leaders, working with teams to develop pragmatic architecture recommendations, delivery plans and owning the overall quality of the features their team ships.

What You'll Do:

Lead, manage, and support key technical initiatives to deploy financial functionality to support Zillow’s growth in new business lines including Zillow Offers.
Drive roadmap and long-term vision for how finance technology works for Zillow Group.
Dive deep on technical solutions across teams, help asking the right questions for technical design, planning, and delivery approach for projects.
Develop and ensure the team is following appropriate planning, testing and execution processes and procedures.
Provide high quality customer service and communicate project status to stakeholders regularly.
Proactively identify, manage and mitigate project risks and find ways to accomplish project goals in the context of dynamic business/technical environments.
Partner and coordinate with cross-functional Zillow Group teams to ensure our managed applications and processes are a success.
Who you are

5-7 years of experience working with custom-built and SaaS development products.
2-3 years working with financial applications.
Proven ability to manage a delivery roadmap across multiple cross-functional business organizations.
Strong communication and interpersonal skills
Demonstrated ability to mix of skills in project management, technology and business processes.
Ability to translate business and technical concepts to technical and non-technical audiences
Bachelor's degree in MIS, Computer Science, Accounting, Finance or equivalent.
"""
#print(mytext)

# %%
# ##############################################################
# Start with loading all necessary libraries
# ##############################################################

import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# ##############################################################
# This section is for file based input of the Job Description
# ##############################################################

# Open a file: file
#file = open('jobdesc.txt',mode='r')
 
# read all lines at once
#text = file.read()
 
# close the file
#file.close()

#print(text)

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(mytext)

# Display the generated image:
plt.rcParams["figure.figsize"] = (12,10)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)
plt.show()
